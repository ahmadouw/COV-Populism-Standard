# %%
from bert_experiments import experiment_run
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Experiment with different BERT models, preprocessing and parameters

# %%
#parameters to set for the experiments
#determine where the model should be saved
file_name = '../data/model/test.model'
#determine where the best model should be saved
best_file_name = '../data/model/test.model'
#determine a set of seeds to be used for multiple runs; amount of runs will depend on that
seeds = [12,23,42,99,1337]
#locations of training, validation and test data
train_path = '../data/gold/train800.csv'
val_path = '../data/gold/val200.csv'
test_path = '../data/gold/test200.csv'
#decide whether the dictionary labelled data is used for training and validation
dict = False
#decide whether spell correction should be done
spelling = False
#provide a model
model_type = 'bert'
model_name = 'bert-base-german-cased'
#determine number of epochs
epochs = 5
#decide if cleaning is enabled
clean = True
experiment_run(train_path,test_path,file_name,best_file_name,seeds,model_type,model_name,epochs,clean, spelling, val_path, dict)

# %%
#parameters to set for the experiments
#determine where the model should be saved
file_name = '../data/model/gold_training_spelling.model'
#determine where the best model should be saved
best_file_name = '../data/model/gold_training_spelling_best.model'
#determine a set of seeds to be used for multiple runs; amount of runs will depend on that
seeds = [12,23,42,99,1337]
#locations of training, validation and test data
train_path = '../data/gold/train800.csv'
val_path = '../data/gold/val200.csv'
test_path = '../data/gold/test200.csv'
#decide whether the dictionary labelled data is used for training and validation
dict = False
#decide whether spell correction should be done
spelling = True
#provide a model
model_type = 'bert'
model_name = 'bert-base-german-cased'
#determine number of epochs
epochs = 5
#decide if cleaning is enabled
clean = True
experiment_run(train_path,test_path,file_name,best_file_name,seeds,model_type,model_name,epochs,clean, spelling, val_path, dict)

# %%
#parameters to set for the experiments
#determine where the model should be saved
file_name = '../data/model/gold_training_spelling_no_clean.model'
#determine where the best model should be saved
best_file_name = '../data/model/gold_training_spelling_no_clean_best.model'
#determine a set of seeds to be used for multiple runs; amount of runs will depend on that
seeds = [12,23,42,99,1337]
#locations of training, validation and test data
train_path = '../data/gold/train800.csv'
val_path = '../data/gold/val200.csv'
test_path = '../data/gold/test200.csv'
#decide whether the dictionary labelled data is used for training and validation
dict = False
#decide whether spell correction should be done
spelling = True
#provide a model
model_type = 'bert'
model_name = 'bert-base-german-cased'
#determine number of epochs
epochs = 5
#decide if cleaning is enabled
clean = False
experiment_run(train_path,test_path,file_name,best_file_name,seeds,model_type,model_name,epochs,clean, spelling, val_path, dict)

# %%
#parameters to set for the experiments
#determine where the model should be saved
file_name = '../data/model/gold_training_no_clean.model'
#determine where the best model should be saved
best_file_name = '../data/model/gold_training_no_clean_best.model'
#determine a set of seeds to be used for multiple runs; amount of runs will depend on that
seeds = [12,23,42,99,1337]
#locations of training, validation and test data
train_path = '../data/gold/train800.csv'
val_path = '../data/gold/val200.csv'
test_path = '../data/gold/test200.csv'
#decide whether the dictionary labelled data is used for training and validation
dict = False
#decide whether spell correction should be done
spelling = False
#provide a model
model_type = 'bert'
model_name = 'bert-base-german-cased'
#determine number of epochs
epochs = 5
#decide if cleaning is enabled
clean = False
experiment_run(train_path,test_path,file_name,best_file_name,seeds,model_type,model_name,epochs,clean, spelling, val_path, dict)

# %%
#parameters to set for the experiments
#determine where the model should be saved
file_name = '../data/model/gold_training_proc_gbert.model'
#determine where the best model should be saved
best_file_name = '../data/model/gold_training_proc_gbert_best.model'
#determine a set of seeds to be used for multiple runs; amount of runs will depend on that
seeds = [12,23,42,99,1337]
#locations of training, validation and test data
train_path = '../data/gold/train800.csv'
val_path = '../data/gold/val200.csv'
test_path = '../data/gold/test200.csv'
#decide whether the dictionary labelled data is used for training and validation
dict = False
#decide whether spell correction should be done
spelling = False
#provide a model
model_type = 'bert'
model_name = 'deepset/gbert-base'
#determine number of epochs
epochs = 5
#decide if cleaning is enabled
clean = True
experiment_run(train_path,test_path,file_name,best_file_name,seeds,model_type,model_name,epochs,clean, spelling, val_path, dict)

# %%
#parameters to set for the experiments
#determine where the model should be saved
file_name = '../data/model/gold_training_spelling_gbert.model'
#determine where the best model should be saved
best_file_name = '../data/model/gold_training_spelling_gbert_best.model'
#determine a set of seeds to be used for multiple runs; amount of runs will depend on that
seeds = [12,23,42,99,1337]
#locations of training, validation and test data
train_path = '../data/gold/train800.csv'
val_path = '../data/gold/val200.csv'
test_path = '../data/gold/test200.csv'
#decide whether the dictionary labelled data is used for training and validation
dict = False
#decide whether spell correction should be done
spelling = True
#provide a model
model_type = 'bert'
model_name = 'deepset/gbert-base'
#determine number of epochs
epochs = 5
#decide if cleaning is enabled
clean = True
experiment_run(train_path,test_path,file_name,best_file_name,seeds,model_type,model_name,epochs,clean, spelling, val_path, dict)

# %%
#parameters to set for the experiments
#determine where the model should be saved
file_name = '../data/model/gold_training_spelling_no_clean_gbert.model'
#determine where the best model should be saved
best_file_name = '../data/model/gold_training_spelling_no_clean_gbert_best.model'
#determine a set of seeds to be used for multiple runs; amount of runs will depend on that
seeds = [12,23,42,99,1337]
#locations of training, validation and test data
train_path = '../data/gold/train800.csv'
val_path = '../data/gold/val200.csv'
test_path = '../data/gold/test200.csv'
#decide whether the dictionary labelled data is used for training and validation
dict = False
#decide whether spell correction should be done
spelling = True
#provide a model
model_type = 'bert'
model_name = 'deepset/gbert-base'
#determine number of epochs
epochs = 5
#decide if cleaning is enabled
clean = False
experiment_run(train_path,test_path,file_name,best_file_name,seeds,model_type,model_name,epochs,clean, spelling, val_path, dict)

# %%
#parameters to set for the experiments
#determine where the model should be saved
file_name = '../data/model/gold_training_no_clean_gbert.model'
#determine where the best model should be saved
best_file_name = '../data/model/gold_training_no_clean_gbert_best.model'
#determine a set of seeds to be used for multiple runs; amount of runs will depend on that
seeds = [12,23,42,99,1337]
#locations of training, validation and test data
train_path = '../data/gold/train800.csv'
val_path = '../data/gold/val200.csv'
test_path = '../data/gold/test200.csv'
#decide whether the dictionary labelled data is used for training and validation
dict = False
#decide whether spell correction should be done
spelling = False
#provide a model
model_type = 'bert'
model_name = 'deepset/gbert-base'
#determine number of epochs
epochs = 5
#decide if cleaning is enabled
clean = False
experiment_run(train_path,test_path,file_name,best_file_name,seeds,model_type,model_name,epochs,clean, spelling, val_path, dict)
